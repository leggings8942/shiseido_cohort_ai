# %%
import pandas as pd

# %%
pdf_main = pd.read_csv('生成ファイル/住所リスト.csv', header=0, index_col=False)
pdf_01   = pd.read_parquet('生成ファイル/01_&フェイス (&Face)_separate.parquet').rename(columns={'total_count':'&Face'})
pdf_02   = pd.read_parquet('生成ファイル/02_medicube (メディキューブ)_separate.parquet').rename(columns={'total_count':'メディキューブ'})
pdf_03   = pd.read_parquet('生成ファイル/03_ONE BY KOSE (ワンバイコーセー)_separate.parquet').rename(columns={'total_count':'ワンバイコーセー'})
pdf_04   = pd.read_parquet('生成ファイル/04_Spa treatment (スパトリートメント)_separate.parquet').rename(columns={'total_count':'スパトリートメント'})
pdf_05   = pd.read_parquet('生成ファイル/05_VODANA (ボダナ)_separate.parquet').rename(columns={'total_count':'ボダナ'})
pdf_06   = pd.read_parquet('生成ファイル/06_YA-MAN (ヤーマン)_separate.parquet').rename(columns={'total_count':'ヤーマン'})
pdf_07   = pd.read_parquet('生成ファイル/07_アスタリフト (ASTALIFT)_separate.parquet').rename(columns={'total_count':'ASTALIFT'})
pdf_08   = pd.read_parquet('生成ファイル/08_アルブラン (ALBLANC)_separate.parquet').rename(columns={'total_count':'ALBLANC'})
pdf_09   = pd.read_parquet('生成ファイル/09_イースペシャル (e-special)_separate.parquet').rename(columns={'total_count':'e-special'})
pdf_10   = pd.read_parquet('生成ファイル/10_インフィニティ (INFINITY)_separate.parquet').rename(columns={'total_count':'INFINITY'})
pdf_11   = pd.read_parquet('生成ファイル/11_エクスイディアル (Exideal)_separate.parquet').rename(columns={'total_count':'Exideal'})
pdf_12   = pd.read_parquet('生成ファイル/12_エレクトロン (ELECTRON)_separate.parquet').rename(columns={'total_count':'ELECTRON'})
pdf_13   = pd.read_parquet('生成ファイル/13_クレイツ (CREATE ION)_separate.parquet').rename(columns={'total_count':'CREATE ION'})
pdf_14   = pd.read_parquet('生成ファイル/14_資生堂 (SHISEIDO)_separate.parquet').rename(columns={'total_count':'SHISEIDO'})
pdf_15   = pd.read_parquet('生成ファイル/15_資生堂メン (SHISEIDO MEN)_separate.parquet').rename(columns={'total_count':'SHISEIDO MEN'})
pdf_16   = pd.read_parquet('生成ファイル/16_ドクターシーラボ (Dr.Ci:Labo)_separate.parquet').rename(columns={'total_count':'Dr.Ci:Labo'})
pdf_17   = pd.read_parquet('生成ファイル/17_トワニー (TWANY)_separate.parquet').rename(columns={'total_count':'TWANY'})
pdf_18   = pd.read_parquet('生成ファイル/18_ハク (HAKU)_separate.parquet').rename(columns={'total_count':'HAKU'})
pdf_19   = pd.read_parquet('生成ファイル/19_ホリスティックキュアーズ (HOLISTIC cures)_separate.parquet').rename(columns={'total_count':'HOLISTIC cures'})
pdf_20   = pd.read_parquet('生成ファイル/20_水橋保寿堂製薬 (エマーキット)_separate.parquet').rename(columns={'total_count':'エマーキット'})
pdf_21   = pd.read_parquet('生成ファイル/21_リバイタル (REVITAL)_separate.parquet').rename(columns={'total_count':'REVITAL'})
pdf_22   = pd.read_parquet('生成ファイル/22_リバイタル グラナス (REVITAL GRANAS)_separate.parquet').rename(columns={'total_count':'REVITAL GRANAS'})
pdf_23   = pd.read_parquet('生成ファイル/23_エリクシール_separate.parquet').rename(columns={'total_count':'エリクシール'})
pdf_24   = pd.read_parquet('生成ファイル/24_クレ・ド・ポー ボーテ_separate.parquet').rename(columns={'total_count':'クレ・ド・ポー ボーテ'})
pdf_25   = pd.read_parquet('生成ファイル/25_クレ・ド・ポー ボーテ シナクティフ_separate.parquet').rename(columns={'total_count':'クレ・ド・ポー ボーテ シナクティフ'})
pdf_26   = pd.read_parquet('生成ファイル/26_ベネフィーク_separate.parquet').rename(columns={'total_count':'ベネフィーク'})
pdf_27   = pd.read_parquet('生成ファイル/27_マキアージュ_separate.parquet').rename(columns={'total_count':'マキアージュ'})

pdf_concat = pdf_main\
				.merge(pdf_01, how='inner', on='caption')\
                .merge(pdf_02, how='inner', on='caption')\
                .merge(pdf_03, how='inner', on='caption')\
                .merge(pdf_04, how='inner', on='caption')\
                .merge(pdf_05, how='inner', on='caption')\
                .merge(pdf_06, how='inner', on='caption')\
                .merge(pdf_07, how='inner', on='caption')\
                .merge(pdf_08, how='inner', on='caption')\
                .merge(pdf_09, how='inner', on='caption')\
                .merge(pdf_10, how='inner', on='caption')\
                .merge(pdf_11, how='inner', on='caption')\
                .merge(pdf_12, how='inner', on='caption')\
                .merge(pdf_13, how='inner', on='caption')\
                .merge(pdf_14, how='inner', on='caption')\
                .merge(pdf_15, how='inner', on='caption')\
                .merge(pdf_16, how='inner', on='caption')\
                .merge(pdf_17, how='inner', on='caption')\
                .merge(pdf_18, how='inner', on='caption')\
                .merge(pdf_19, how='inner', on='caption')\
                .merge(pdf_20, how='inner', on='caption')\
                .merge(pdf_21, how='inner', on='caption')\
                .merge(pdf_22, how='inner', on='caption')\
                .merge(pdf_23, how='inner', on='caption')\
                .merge(pdf_24, how='inner', on='caption')\
                .merge(pdf_25, how='inner', on='caption')\
                .merge(pdf_26, how='inner', on='caption')\
                .merge(pdf_27, how='inner', on='caption')

pdf_concat.to_csv('生成ファイル/cohort.csv', header=True, index=False)
pdf_concat
# Out:
#                caption                        address   &Face  メディキューブ  \
# 0    ﾖﾄﾞﾊﾞｼﾏﾙﾁﾒﾃﾞｨｱ梅田店                大阪府大阪市　北区大深町１－１  522453   530049
# 1             アル・プラザ鶴見  岐阜県　大垣市　鶴見町字上渡瀬６４１－２１Ｆ資生堂コーナー   11912    12125
# 2           フレンドマート開発店               福井県福井市開発２丁目１０１番地   12905    13118
# 3           アルプラフーズ大河端              石川県金沢市大河端町西２丁目１５番    7336     7462
# 4               平和堂江南店       愛知県江南市上奈良町栄６１－３１Ｆ資生堂コーナー   12663    12908
# ..                 ...                            ...     ...      ...
# 114       オークワパームＣ和歌山店                 和歌山県和歌山市中野３１－１   13586    13850
# 115       オークワパビリオンＣ田辺              和歌山県田辺市稲成町新江原３１６５    9314     9442
# 116         オークワ新宮仲之町店               和歌山県新宮市丹鶴二丁目１番１号    4583     4659
# 117        オークワロマンＣ御坊店                和歌山県御坊市湯川町財部１８１    4437     4506
# 118        オークワＳＣ和泉納花店                  大阪府　和泉市納花町３１３   14273    14489
#
#      ワンバイコーセー  スパトリートメント     ボダナ    ヤーマン  ASTALIFT  ALBLANC  ...    HAKU  \
# ...
